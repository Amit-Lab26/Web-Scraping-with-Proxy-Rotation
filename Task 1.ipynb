# %%
import requests
from bs4 import BeautifulSoup
import sys
import time
import json

# %%
page=requests.get("https://magicpin.in/New-Delhi/Paharganj/Restaurant/Eatfit/store/61a193/delivery/")

# %%
page
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(page.text,'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html dir="ltr" lang="en-in">
# <head>
# <title>  Save 15% with Delivery Offers on
#         EatFit, Paharganj, New Delhi  | December 2023
#     </title>
# <script>
#         window.dataLayerParams = [{
#             "page_type": "merchantpage_delivery",
#             "affiliate": 'customer_web'
#         }];
#     </script>
# <link href="https://static.magicpin.com/samara/media/blog/13-04-2023-favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="https://static.magicpin.com/samara/media/blog/13-04-2023-favicon.ico" rel="icon" type="image/x-icon">
# <link crossorigin="" href="https://static.magicpin.com/" rel="preconnect"/>
# <link href="https://static.magicpin.com/" rel="dns-prefetch"/>
# <link crossorigin="" href="https://lh3.googleusercontent.com/" rel="preconnect"/>
# <link href="https://lh3.googleusercontent.com/" rel="dns-prefetch"/>
# <meta content="Best offers, deals, discounts on EatFit, Paharganj, New Delhi. EatFit, Paharganj, New Delhi vouchers, coupons, home delivery and discounts - magicpin" itemprop="description" name="description"/>
# <link href="https://magicpin.in/New-Delhi/Paharganj/Restaurant/Eatfit/store/61a193/delivery/" rel="canonical"/>
# <meta content="EatFit in Paharganj, EatFit in New Delhi, Healthy Food, North Indian, Pizza, Burger, Pasta, Biryani, Chinese, Cloud Kitchen, , Menu, Reviews, Order Food, Visit Store &amp; Buy Vouchers, Contact Number, Phone Number, Address, Map, Ratings, Directions, Working Hours, Services" name="keywords"/>
# <meta content="IN-DL" name="geo.region">
# <meta content="Paharganj, New Delhi" name="geo.placename"/>
# <meta content="28.6409887;77.2101869" name="geo.position"/>
# <meta content="28.6409887, 77.2101869" name="ICBM"/>
# <script type="application/ld+json">
#         {
#             "@context": "https://schema.org",
#             "@type": "WebSite",
#             "name": "magicpin",
#             "url": "https://www.magicpin.in",
#             "inLanguage": "en"
#         }
#     </script>
# <script type="application/ld+json">
#         {
#             "@context": "https://schema.org",
#             "@id":"https://magicpin.in/New-Delhi/Paharganj/Restaurant/Eatfit/store/61a193/",
#
#             "@type": "Restaurant",
#
#             "name": "Eatfit",
#             "description": "EatFit is a fast-casual restaurant that specializes in serving up healthy and nutritious meals for those looking for a quick and convenient option. The restaurant has a clean and modern atmosphere, with a focus on providing a healthy and energizing environment for diners. The menu features a range of options, including fresh salads, whole grain bowls, and protein-packed dishes, each made with the freshest and healthiest ingredients. Diners can expect to find flavorful and satisfying meals, without the added guilt of excess calories or unhealthy ingredients. Whether you&#39;re looking for a light and refreshing lunch or a hearty and nutritious dinner, EatFit has something for everyone. With its commitment to providing delicious and healthy meals, it&#39;s a popular spot for health-conscious diners and those looking for a convenient and satisfying option.",
#             "hasMenu": "https://magicpin.in/New-Delhi/Paharganj/Restaurant/Eatfit/store/61a193/menu/",
#             "url": "https://magicpin.in/New-Delhi/Paharganj/Restaurant/Eatfit/store/61a193/",
#
#             "servesCuisine": "Healthy Food, North Indian, Pizza, Burger, Pasta, Biryani, Chinese, Cloud Kitchen",
#
#             "priceRange": "Cost for two: ₹399",
#
#
#             "geo": {
#                 "@type": "GeoCoordinates",
#                 "latitude": "28.6409887",
#                 "longitude": "77.2101869"
#             },
#
#
#             "openingHoursSpecification": [
#
#                 {
#                 "@type": "OpeningHoursSpecification",
#                 "dayOfWeek": [
#                     "FRIDAY"
#                 ],
#
#                 "opens": "07:00:00",
#
#
#                 "closes": "23:45:00"
#
#                 },
#
#                 {
#                 "@type": "OpeningHoursSpecification",
#                 "dayOfWeek": [
#                     "MONDAY"
#                 ],
#
#                 "opens": "07:00:00",
#
#
#                 "closes": "23:45:00"
#
#                 },
#
#                 {
#                 "@type": "OpeningHoursSpecification",
#                 "dayOfWeek": [
#                     "SATURDAY"
#                 ],
#
#                 "opens": "07:00:00",
#
#
#                 "closes": "23:45:00"
#
#                 },
#
#                 {
#                 "@type": "OpeningHoursSpecification",
#                 "dayOfWeek": [
#                     "SUNDAY"
#                 ],
#
#                 "opens": "07:00:00",
#
#
#                 "closes": "23:45:00"
#
#                 },
#
#                 {
#                 "@type": "OpeningHoursSpecification",
#                 "dayOfWeek": [
#                     "THURSDAY"
#                 ],
#
#                 "opens": "07:00:00",
#
#
#                 "closes": "23:45:00"
#
#                 },
#
#                 {
#                 "@type": "OpeningHoursSpecification",
#                 "dayOfWeek": [
#                     "TUESDAY"
#                 ],
#
#                 "opens": "07:00:00",
#
#
#                 "closes": "23:45:00"
#
#                 },
#
#                 {
#                 "@type": "OpeningHoursSpecification",
#                 "dayOfWeek": [
#                     "WEDNESDAY"
#                 ],
#
#                 "opens": "07:00:00",
#
#
#                 "closes": "23:45:00"
#
#                 }
#
#             ],
#
#             "image": "https://lh3.googleusercontent.com/E9RiSdrWUltyEzOrAguHR_5x512zsPddIkPH1k5ZH70ZR4r3KLov6kELxPDxqlHkkWN2mSI00gAjpabgUy1TzhhKJDLXxR7NffHEGg4=w300-rw",
#             "address": {
#                 "addressLocality": "New Delhi",
#                 "addressRegion": "DL",
#                 "streetAddress": "1830\u002D1831, Gf, Laxmi Narain Street, Chuna Mandi, Paharganj, Delhi, New Delhi, Delhi\u002D110055, Paharganj, New Delhi",
#                 "addressCountry": "IN",
#                 "@type": "PostalAddress"
#             },
#             "hasMap": "https://www.google.com/maps/search/?api=1&query=28.6409887,77.2101869",
#
#             "currenciesAccepted": "INR"
#
#             ,
#                 "aggregateRating": {
#                     "reviewCount": 44,
#                     "@type": "AggregateRating",
#                     "ratingValue": 3,
#                     "bestRating": 5.0,
#                     "worstRating": 0.0
#                 }
#                 ,
#                     "review": [
#
#                         {
#                             "@type": "Review",
#                             "reviewRating": {
#                                 "@type": "Rating",
#                                 "ratingValue": 5,
#                                 "bestRating": 5.0,
#                                 "worstRating": 0.0
#                             },
#                             "datePublished": "",
#                             "description": "EatFit is a great spot to grab a quick bite! The Dilli Kulcha Burger Combo was delicious and surprisingly filling. Highly recommend trying it out!",
#                             "author": {
#                                 "@type": "Person",
#                                 "name": "Udita Singh"
#                             }
#                         },
#
#                         {
#                             "@type": "Review",
#                             "reviewRating": {
#                                 "@type": "Rating",
#                                 "ratingValue": 1,
#                                 "bestRating": 5.0,
#                                 "worstRating": 0.0
#                             },
#                             "datePublished": "",
#                             "description": "Chilli chicken was old
# Even the vegetables given as salad had a rotten taste.
# Worst ever food
# ",
#                             "author": {
#                                 "@type": "Person",
#                                 "name": "AKSHAJ S"
#                             }
#                         },
#
#                         {
#                             "@type": "Review",
#                             "reviewRating": {
#                                 "@type": "Rating",
#                                 "ratingValue": 5,
#                                 "bestRating": 5.0,
#                                 "worstRating": 0.0
#                             },
#                             "datePublished": "",
#                             "description": "I recently visited EatFit and tried the Butter Paneer Kulcha Burger. It was heavenly! The Paneer was so soft and the combination of flavors in the burger was spot on. Highly recommend!",
#                             "author": {
#                                 "@type": "Person",
#                                 "name": "Divya Shukla"
#                             }
#                         },
#
#                         {
#                             "@type": "Review",
#                             "reviewRating": {
#                                 "@type": "Rating",
#                                 "ratingValue": 2,
#                                 "bestRating": 5.0,
#                                 "worstRating": 0.0
#                             },
#                             "datePublished": "",
#                             "description": "Still need to focus on food processing and coordination with delivery partners for fast food delivery",
#                             "author": {
#                                 "@type": "Person",
#                                 "name": "Dass Arun"
#                             }
#                         },
#
#                         {
#                             "@type": "Review",
#                             "reviewRating": {
#                                 "@type": "Rating",
#                                 "ratingValue": 5,
#                                 "bestRating": 5.0,
#                                 "worstRating": 0.0
#                             },
#                             "datePublished": "",
#                             "description": "Everything was just perfect ❤️",
#                             "author": {
#                                 "@type": "Person",
#                                 "name": "Bhavya Pahuja"
#                             }
#                         },
#
#                         {
#                             "@type": "Review",
#                             "reviewRating": {
#                                 "@type": "Rating",
#                                 "ratingValue": 1,
#                                 "bestRating": 5.0,
#                                 "worstRating": 0.0
#                             },
#                             "datePublished": "",
#                             "description": "Ordered two non veg kulcha burger. One of them is vegetarian",
#                             "author": {
#                                 "@type": "Person",
#                                 "name": "Amit Arya"
#                             }
#                         },
#
#                         {
#                             "@type": "Review",
#                             "reviewRating": {
#                                 "@type": "Rating",
#                                 "ratingValue": 1,
#                                 "bestRating": 5.0,
#                                 "worstRating": 0.0
#                             },
#                             "datePublished": "",
#                             "description": "Overcooked taste less wastage of money",
#                             "author": {
#                                 "@type": "Person",
#                                 "name": "Jyoti maurya"
#                             }
#                         },
#
#                         {
#                             "@type": "Review",
#                             "reviewRating": {
#                                 "@type": "Rating",
#                                 "ratingValue": 3,
#                                 "bestRating": 5.0,
#                                 "worstRating": 0.0
#                             },
#                             "datePublished": "",
#                             "description": "No bill provided and no mention of the brand on  provided bottles",
#                             "author": {
#                                 "@type": "Person",
#                                 "name": "Rachit v"
#                             }
#                         },
#
#                         {
#                             "@type": "Review",
#                             "reviewRating": {
#                                 "@type": "Rating",
#                                 "ratingValue": 1,
#                                 "bestRating": 5.0,
#                                 "worstRating": 0.0
#                             },
#                             "datePublished": "",
#                             "description": "Taste not good",
#                             "author": {
#                                 "@type": "Person",
#                                 "name": "Dass Arun"
#                             }
#                         }
#
#                     ]
#
#
#         }
#         </script>
# <link as="image" fetchpriority="high" href="https://lh3.googleusercontent.com/E9RiSdrWUltyEzOrAguHR_5x512zsPddIkPH1k5ZH70ZR4r3KLov6kELxPDxqlHkkWN2mSI00gAjpabgUy1TzhhKJDLXxR7NffHEGg4=w300-rw" rel="preload"/>
# <meta content="EatFit, Paharganj, New Delhi - magicpin" property="og:title"/>
# <meta content="magicpin" property="og:site_name"/>
# <meta content="https://magicpin.in/New-Delhi/Paharganj/Restaurant/Eatfit/store/61a193/" property="og:url"/>
# <meta content="EatFit, Paharganj, New Delhi; View menu, reviews, customer ratings, contact number, customer selfies and more on magicpin. Best Restaurant in Paharganj, New Delhi. EatFit serves  Healthy Food,  North Indian,  Pizza,  Burger,  Pasta,  Biryani,  Chinese,  Cloud Kitchen, " property="og:description"/>
# <meta content="https://lh3.googleusercontent.com/E9RiSdrWUltyEzOrAguHR_5x512zsPddIkPH1k5ZH70ZR4r3KLov6kELxPDxqlHkkWN2mSI00gAjpabgUy1TzhhKJDLXxR7NffHEGg4=w300-rw" property="og:image"/>
# <meta content="website" property="og:type"/>
# <meta content="462422103909005" property="fb:app_id"/>
# <meta content="https://magicpin.in" property="article:author">
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="@mymagicpin" name="twitter:site"/>
# <meta content="EatFit, Paharganj, New Delhi - magicpin" name="twitter:title"/>
# <meta content="EatFit, Paharganj, New Delhi; View menu, reviews, customer ratings, contact number, customer selfies and more on magicpin. Best Restaurant in Paharganj, New Delhi. EatFit serves  Healthy Food,  North Indian,  Pizza,  Burger,  Pasta,  Biryani,  Chinese,  Cloud Kitchen, " name="twitter:description"/>
# <meta content="https://lh3.googleusercontent.com/E9RiSdrWUltyEzOrAguHR_5x512zsPddIkPH1k5ZH70ZR4r3KLov6kELxPDxqlHkkWN2mSI00gAjpabgUy1TzhhKJDLXxR7NffHEGg4=w300-rw" name="twitter:image"/>
# <script defer="" src="https://static.magicpin.com/samara/static/js/build/Merchants.js.gz?v=722"></script>
# <meta content="!" name="fragment"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0" name="viewport">
# <meta content="yes" name="apple-mobile-web-app-capable">
# <meta content="#338aed" name="theme-color">
# <meta content="cZQ0ec_BK_klv5OO6jSpvj4UpCD9zAasW8U8iZeYxVg" name="google-site-verification">
# <meta content="7b683b2c7a1a4bde9bd8c5a2575e1583" name="p:domain_verify">
# <meta content="noodp, noydir" name="robots">
# <meta content="upgrade-insecure-requests" http-equiv="Content-Security-Policy"/>
# <!--[if lt IE 9]>
#         <script src="//html5shim.googlecode.com/svn/trunk/html5.js"></script>
#     <![endif]-->
# <script type="text/javascript">
#         function imgLoaded(img){
#             var imgWrapper = img.parentNode;
#             imgWrapper.className += imgWrapper.className ? ' loaded' : 'loaded';
#         };
#     </script>
# <link as="style" href="https://static.magicpin.com/samara/static/build/Merchant.css.gz?v=722" rel="preload"/>
# <link href="https://static.magicpin.com/samara/static/build/Merchant.css.gz?v=722" rel="stylesheet"/>
# <script>
#         var hostName = document.location.hostname;
#         (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#         (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#         m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#         })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#         let trackingIDmagicpin = "UA-66063161-1";
#         let trackingIDOrderHere = "UA-66063161-4";
#         let trackingID = hostName.search("orderhere.io") === -1 ? trackingIDmagicpin : trackingIDOrderHere;
#         ga('create', trackingID, 'auto');
#         ga('set', 'contentGroup1', 'merchantpage_delivery');
#         ga('set', 'contentGroup2', 'customer_web');
#         ga('send', 'pageview');
#     </script>
# <noscript>
# <style>
#             .magicpin-loader { display: none; }
#         </style>
# </noscript>
# <script type="text/javascript">
#         var link  = document.createElement('link');
#         link.id = 'manifest';
#         link.rel  = 'manifest';
#         var hostName = document.location.hostname
#         if (hostName.search("orderhere.io") !== -1 ) {
#             link.href = 'https://static.magicpin.com/samara/static/js/orderhere/manifest.json';
#         }else{
#             link.href = 'https://static.magicpin.com/samara/static/js/base/manifest.json';
#         }
#         document.getElementsByTagName('head')[0].appendChild(link);
#     </script>
# <!-- Google tag (gtag.js) -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-5WL04EQ1ST"></script>
# <script>
#         window.dataLayer = window.dataLayer || [];
#         function gtag(){dataLayer.push(arguments);}
#         gtag('js', new Date());
#
#         gtag('config', 'G-5WL04EQ1ST', {
#             'page_type': 'merchantpage_delivery',
#             'client': 'customer_web',
#         });
#     </script>
# </meta></meta></meta></meta></meta></meta></meta></meta></link></head>
# <body>
# <div id="new-user-reward-popup-react"></div>
# <section class="persisted-cart-holder show-mb">
# <div id="persisted-cart-react"></div>
# </section>
# <div class="custom-banner-container">
# <section id="custom-banner-react"></section>
# </div>
# <div id="exit-subscribe-popup-react"></div>
# <div class="alert-bar-banner-holder" id="alert-bar-banner-react"></div>
# <div class="header-placeholder"></div>
# <header class="site-header">
# <div class="container">
# <div class="mobile-loader-overlay">
# <div class="mobile-loader-holder">
# <div class="mobile-loader"></div>
# </div>
# </div>
# <section class="header">
# <div class="logo-location-holder">
# <a data-type="header-logo" href="/"><img alt="magicpin logo - discover deals,discounts and vouchers around you" class="logo" height="16" src="https://static.magicpin.com/samara/static/images/logo-v1.svg" width="62"/></a>
# <div class="location-header-react" id="location-header-react">
# <section class="location-holder show-mb">
# <p class="location"> Select Location </p>
# <img alt="location dropdown icon" class="dropdown-image" height="16" src="https://static.magicpin.com/samara/static/images/dropdown.svg" width="16"/>
# </section>
# </div>
# </div>
# <section class="header-search hide-mb" id="header-search-react"></section>
# <div class="action-cta-holder">
# <div class="user-holder" id="react-login-popover">
# <button class="user">
#                                 Login
#                             </button>
# </div>
# <button class="search show-mb" id="universal-search-react">
# <img alt="search icon" height="16" src="https://static.magicpin.com/samara/static/images/common/search-gray.svg" width="16">
# </img></button>
# <div class="redeem-voucher-cta-holder" id="user-active-vouchers-react"></div>
# <div class="hamburger-holder" id="react-menu-popover"><img alt="hamburger icon" class="hamburger" height="24" src="https://static.magicpin.com/samara/static/images/common/hamburger-gray.svg" width="24"/></div>
# </div>
# </section>
# </div>
# </header>
# <div class="merchant-holder">
# <div class="merchant-details">
# <div class="merchant-details-holder">
# <div class="grid-sizer"></div>
# <div class="gutter-sizer"></div>
# <div class="breadcrumbs-holder hide-mb">
# <ol class="breadcrumbs merchant-brick hide-mb" itemscope="" itemtype="https://schema.org/BreadcrumbList">
# <li itemprop="itemListElement" itemscope="" itemtype="https://schema.org/ListItem">
# <span itemprop="name">
# <a data-type="merchant-breadcrumb" href="https://magicpin.in/" itemprop="item" onclick="sendEvent('web_merchantpage_delivery', 'click', 'breadcrumb_home', {'subject_type': 'merchant', 'subject_id': '19401813'});">Home</a>
# </span>
# <meta content="1" itemprop="position">
# </meta></li>
# <li itemprop="itemListElement" itemscope="" itemtype="https://schema.org/ListItem">
# <span itemprop="name">
# <a data-type="merchant-breadcrumb" href="https://magicpin.in/india/" itemprop="item" onclick="sendEvent('web_merchantpage_delivery', 'click', 'breadcrumb_india', {'subject_type': 'merchant', 'subject_id': '19401813'});">India</a>
# </span>
# <meta content="2" itemprop="position">
# </meta></li>
# <li itemprop="itemListElement" itemscope="" itemtype="https://schema.org/ListItem">
# <span itemprop="name">
# <a data-type="merchant-breadcrumb" href="https://magicpin.in/india/New-Delhi/All/Restaurant/" itemprop="item" onclick="sendEvent('web_merchantpage_delivery', 'click', 'breadcrumb_city', {'subject_type': 'merchant', 'subject_id': '19401813'});">New Delhi</a>
# </span>
# <meta content="3" itemprop="position">
# </meta></li>
# <li itemprop="itemListElement" itemscope="" itemtype="https://schema.org/ListItem">
# <span itemprop="name">
# <a data-type="merchant-breadcrumb" href="https://magicpin.in/india/New-Delhi/Paharganj/Restaurant/" itemprop="item" onclick="sendEvent('web_merchantpage_delivery', 'click', 'breadcrumb_locality', {'subject_type': 'merchant', 'subject_id': '19401813'});">Paharganj</a>
# </span>
# <meta content="4" itemprop="position">
# </meta></li>
# <li itemprop="itemListElement" itemscope="" itemtype="https://schema.org/ListItem">
# <span itemprop="name">
# <a data-type="merchant-breadcrumb" href="https://magicpin.in/india/New-Delhi/Paharganj/Restaurant/" itemprop="item" onclick="sendEvent('web_merchantpage_delivery', 'click', 'breadcrumb_category', {'subject_type': 'merchant', 'subject_id': '19401813'});">Restaurant</a>
# </span>
# <meta content="5" itemprop="position">
# </meta></li>
# <li itemprop="itemListElement" itemscope="" itemtype="https://schema.org/ListItem">
# <span itemprop="name">
# <a data-type="merchant-breadcrumb" href="https://magicpin.in/New-Delhi/Paharganj/Restaurant/Eatfit/store/61a193/" itemprop="item" onclick="sendEvent('web_merchantpage_delivery', 'click', 'breadcrumb_mer_name', {'subject_type': 'merchant', 'subject_id': '19401813'});">EatFit</a>
# </span>
# <meta content="6" itemprop="position">
# </meta></li>
# <li itemprop="itemListElement" itemscope="" itemtype="https://schema.org/ListItem">
# <span itemprop="name">
# <a data-type="merchant-breadcrumb" href="https://magicpin.in/New-Delhi/Paharganj/Restaurant/Eatfit/store/61a193/delivery/" itemprop="item">Delivery</a>
# </span>
# <meta content="7" itemprop="position">
# </meta></li>
# </ol>
# </div>
# <header class="merchant-brick merchant-header">
# <div class="show-mb" id="merchant-photos-react" style="height: 212px;">
# <div class="merchant-cover-holder v2">
# <article class="merchant-cover-images">
# <div class="image-container" style="width: 85vw;">
# <img class="merchant-logo" src="https://lh3.googleusercontent.com/e6qenVR_6CpTDcCGk7E8cFuGtgl6UL6s7dYr-cQbfExFDaNL1GjVtP-MVsXUsFOpqrTQE7ommX9M-fhUzAYN-JOnCLnZ9lpw_TPuxOynwg=w256-rw"/>
# <img class="merchant-image" src="https://lh3.googleusercontent.com/E9RiSdrWUltyEzOrAguHR_5x512zsPddIkPH1k5ZH70ZR4r3KLov6kELxPDxqlHkkWN2mSI00gAjpabgUy1TzhhKJDLXxR7NffHEGg4=w300-rw" style="width: 85vw"/>
# </div>
# <div class="image-container">
# <img class="merchant-image" src="https://lh3.googleusercontent.com/k-iN-Gta3oUpCYBSGHRPsDpo5Cv4lstaI6eAdK_1PBy0z_ofmJwL1R4P6pnRsWMNEkg0slV0UUwWf80yRDa7Dw2hZdxfdJzO7DKG89WhmA=w1200-rw"/>
# </div>
# </article>
# </div>
# </div>
# <section class="merchant-header-info" style="margin-top: 0; padding-top: 0;">
# <a class="merchant-logo-holder hide-mb" data-type="merchant-logo" href="https://magicpin.in/New-Delhi/Paharganj/Restaurant/Eatfit/store/61a193/">
# <img alt="EatFit, Paharganj, New Delhi logo" class="merchant-logo hide-mb" loading="lazy" src="https://lh3.googleusercontent.com/e6qenVR_6CpTDcCGk7E8cFuGtgl6UL6s7dYr-cQbfExFDaNL1GjVtP-MVsXUsFOpqrTQE7ommX9M-fhUzAYN-JOnCLnZ9lpw_TPuxOynwg=w100-rw" title="EatFit, Paharganj, New Delhi"/>
# </a>
# <section class="merchant-name">
# <h1 class="v2"><a data-type="merchant-name" href="https://magicpin.in/New-Delhi/Paharganj/Restaurant/Eatfit/store/61a193/">EatFit</a></h1>
# <p class="merchant-establishment show-mb"> Delivery Only
#
#                                     <span>
#                                         . Cost for two: ₹399
#                                     </span>
# </p>
# <p class="merchant-establishment hide-mb">
#                                     Delivery Only
#                                     <span class="merchant-sub-content cft">Cost for two: ₹399</span>
# </p>
# <h2 class="merchant-address-details" title="Restaurant related to EatFit, Paharganj, New Delhi">
# <a class="merchant-locality" data-type="merchant-locality" href="https://magicpin.in/india/New-Delhi/Paharganj/Restaurant/" onclick="sendEvent('web_merchantpage_delivery', 'click', 'locality_cover_image')">
#                                     Paharganj, New Delhi.
#                                 </a>
# </h2>
# <section class="detail-sub-section merchant-timings">
# <div class="merchant-timing-container" id="merchant-timing-react">
# </div>
# </section>
# </section>
# <section class="merchant-rating v2" onclick="goToReviews()">
# <div class="rating-content-header" style="background-color:#8bcc00; border-color:#8bcc00;">
# <img alt="star icon" class="star" src="https://static.magicpin.com/samara/static/images/merchant/star-white.svg"/>
# <p class="rating-desc">3.0</p>
# </div>
# <div class="merchant-visits">44 visits</div>
# </section>
# </section>
# <section class="merchant-actions show-mb">
# <a class="merchant-action" href="https://magicpin.in/New-Delhi/Paharganj/Restaurant/Eatfit/store/61a193/menu/" onclick="sendEvent('web_merchantpage_delivery', 'click', 'merchant_menu_cta', {'subject_type': '1', 'subject_id': '19401813'});">
# <img alt="menu" class="action-icon" src="https://static.magicpin.com/samara/static/images/merchant/menu-icon-new.svg"/>
# <span class="action-text"> Menu </span>
# </a>
# <a class="merchant-action" href="https://www.google.com/maps/search/?api=1&amp;query=28.6409887,77.2101869" onclick="sendEvent('web_merchantpage_delivery', 'click', 'merchant_directions_cta', {'subject_type': 'merchant', 'subject_id': '19401813'});">
# <img alt="navigation icon " class="action-icon" src="https://static.magicpin.com/samara/static/images/merchant/distance.svg"/>
# <span class="action-text"> Directions </span>
# </a>
# </section>
# <!-- -->
# <section class="merchant-description hide-mb" style="max-height: 40px; overflow: hidden;">
#                         EatFit is a fast-casual restaurant that specializes in serving up healthy and nutritious meals for those looking for a quick and convenient option. The restaurant has a clean and modern atmosphere, with a focus on providing a healthy and energizing environment for diners. The menu features a range of options, including fresh salads, whole grain bowls, and protein-packed dishes, each made with the freshest and healthiest ingredients. Diners can expect to find flavorful and satisfying meals, without the added guilt of excess calories or unhealthy ingredients. Whether you're looking for a light and refreshing lunch or a hearty and nutritious dinner, EatFit has something for everyone. With its commitment to providing delicious and healthy meals, it's a popular spot for health-conscious diners and those looking for a convenient and satisfying option.
#                     </section>
# <div class="get-cashback-message">
# <p>Please visit magicpin.in/phonepe/inappview</p>
# <img alt="close" class="close-cashback-message" onclick="closeCashbackMessage()" src="https://static.magicpin.com/samara/static/images/close-white.svg">
# </img></div>
# <div class="merchant-strips-container" id="merchant-strips-react">
# <div class="merchant-actions-container">
# </div>
# </div>
# <div id="nav-holder">
# <nav class="merchant-navigation">
# <a class="" data-type="merchant-nav-info" href="https://magicpin.in/New-Delhi/Paharganj/Restaurant/Eatfit/store/61a193/" onclick="sendEvent('web_merchantpage_delivery', 'click', 'merchant_nav_overview', {'subject_type': 'merchant', 'subject_id': '19401813'});">Overview</a>
# <a class="delivery-tab active" data-type="merchant-nav-magicorder" href="https://magicpin.in/New-Delhi/Paharganj/Restaurant/Eatfit/store/61a193/delivery/" onclick="sendEvent('web_merchantpage_delivery', 'click', 'merchant_nav_magicorder', {'subject_type': 'merchant', 'subject_id': '19401813'});" style="position: relative;">
#
#                                             Delivery
#
#                                         <span class="save-highlight hide-mb">
# <span>
#                                                 Save 15%
#                                             </span>
# </span>
# </a>
# <a class="" data-type="merchant-nav-menu" href="https://magicpin.in/New-Delhi/Paharganj/Restaurant/Eatfit/store/61a193/menu/" onclick="sendEvent('web_merchantpage_delivery', 'click', 'merchant_nav_menu', {'subject_type': 'merchant', 'subject_id': '19401813'});">Menu</a>
# <a class="" data-type="merchant-nav-reviews" href="https://magicpin.in/New-Delhi/Paharganj/Restaurant/Eatfit/store/61a193/reviews/" onclick="sendEvent('web_merchantpage_delivery', 'click', 'merchant_nav_reviews', {'subject_type': 'merchant', 'subject_id': '19401813'});">Reviews</a>
# <a class="" data-type="merchant-nav-photos" href="https://magicpin.in/New-Delhi/Paharganj/Restaurant/Eatfit/store/61a193/photos/" onclick="sendEvent('web_merchantpage_delivery', 'click', 'merchant_nav_photos', {'subject_type': 'merchant', 'subject_id': '19401813'});">Photos</a>
# </nav>
# </div>
# </header>
# <div class="merchant-brick magicOrderContainer" id="magic-order-react" style="padding: 0; transform: none;">
# <article class="deliveryDetailsHolder" id="deliveryDetails">
# <div class="achievement-holder">
# <div class="achievement">
# <img alt="icon" class="icon" src="https://lh3.googleusercontent.com/NE0kdxFvatTNkZJGAzeKDh_Von3GmhtFvI9xssnpnnz1TFcxBoZ2RbEFR7zYIS8eITA5XoJOjJQfZCg8muz1LkxjpQI8lWJhwVid3G18">
# <p class="achievement-title">
#                             Delivery: 44 mins
#                         </p>
# </img></div>
# <div class="achievement">
# <img alt="icon" class="icon" src="https://lh3.googleusercontent.com/uk_-gYIFUNuaOi-u2fFRk5Y09PmhTSGEeGqVCVF31mBYzxSFlvPUpb7HCE07KI4f3J1wSCTeGOlzdCNK12BPRiLRZD-ut_9gbKzq2Wk2">
# <p class="achievement-title">
#                             FREE DELIVERY on order above ₹349
#                         </p>
# </img></div>
# </div>
# </article>
# <div class="searchBarHolder" id="searchBarCatalog">
# <div class="inputElementHolder">
# <img alt="" class="searchIcon" src="https://static.magicpin.com/samara/static/images/search-copy.svg">
# <input class="inputElement" placeholder="Search" type="text"/>
# </img></div>
# </div>
# <div class="onlineLogoHolder">
# <img class="orderOnlineIcon" src="https://static.magicpin.com/samara/static/images/merchant/magicOrder/order-online-logo.svg"/>
# <span>
#         Order Online
#     </span>
# </div>
# <div class="catalogItemsHolder">
# <article class="categoryListing">
# <h4 class="categoryHeading"> Kulcha Burger </h4>
# <section class="categoryItemHolder">
# <div class="itemDetails itemWithImage">
# <a href="https://magicpin.in/New-Delhi/Paharganj/Restaurant/product/Veg-Keema-Kulcha-Burger/?itemId=2857673&amp;mid=19401813&amp;utm_source=popular_items&amp;lat=28.6409887&amp;lon=77.2101869">
# <span class="itemImageHolder">
# <img alt="Veg Keema Kulcha Burger image" class="itemImage" src="https://static.magicpin.com/samara/static/images/blank-placeholder.svg"/>
# </span>
# </a>
# <article class="itemInfo">
# <a class="itemName" href="https://magicpin.in/New-Delhi/Paharganj/Restaurant/product/Veg-Keema-Kulcha-Burger/?itemId=2857673&amp;mid=19401813&amp;utm_source=popular_items&amp;lat=28.6409887&amp;lon=77.2101869">Veg Keema Kulcha Burger</a>
# <p>
# <span class="itemPrice"> ₹239 </span>
# </p>
# <section class="description">
#                                     Bite into the soft layers of desi kulcha burger, spread with creamy ch
#                                 </section>
# </article>
# </div>
# <article class="itemCountHolder">
# <div>
# <button class="countCta add">Loading</button>
# </div>
# </article>
# </section>
# <section class="categoryItemHolder">
# <div class="itemDetails itemWithImage">
# <a href="https://magicpin.in/New-Delhi/Paharganj/Restaurant/product/Peri-Peri-Paneer-Kulcha-Burger/?itemId=2857674&amp;mid=19401813&amp;utm_source=popular_items&amp;lat=28.6409887&amp;lon=77.2101869">
# <span class="itemImageHolder">
# <img alt="Peri-Peri Paneer Kulcha Burger image" class="itemImage" src="https://static.magicpin.com/samara/static/images/blank-placeholder.svg"/>
# </span>
# </a>
# <article class="itemInfo">
# <a class="itemName" href="https://magicpin.in/New-Delhi/Paharganj/Restaurant/product/Peri-Peri-Paneer-Kulcha-Burger/?itemId=2857674&amp;mid=19401813&amp;utm_source=popular_items&amp;lat=28.6409887&amp;lon=77.2101869">Peri-Peri Paneer Kulcha Burger</a>
# <p>
# <span class="itemPrice"> ₹308 </span>
# </p>
# <section class="description">
#                                     [Energy - 668Cal | Protein - 29gm] Bite into the flavourful layers of
#                                 </section>
# </article>
# </div>
# <article class="itemCountHolder">
# <div>
# <button class="countCta add">Loading</button>
# </div>
# </article>
# </section>
# <section class="categoryItemHolder">
# <div class="itemDetails itemWithImage">
# <a href="https://magicpin.in/New-Delhi/Paharganj/Restaurant/product/Peri-Peri-Chicken-Kulcha-Burger/?itemId=2857671&amp;mid=19401813&amp;utm_source=popular_items&amp;lat=28.6409887&amp;lon=77.2101869">
# <span class="itemImageHolder">
# <img alt="Peri-Peri Chicken Kulcha Burger image" class="itemImage" src="https://static.magicpin.com/samara/static/images/blank-placeholder.svg"/>
# </span>
# </a>
# <article class="itemInfo">
# <a class="itemName" href="https://magicpin.in/New-Delhi/Paharganj/Restaurant/product/Peri-Peri-Chicken-Kulcha-Burger/?itemId=2857671&amp;mid=19401813&amp;utm_source=popular_items&amp;lat=28.6409887&amp;lon=77.2101869">Peri-Peri Chicken Kulcha Burger</a>
# <p>
# <span class="itemPrice"> ₹319 </span>
# </p>
# <section class="description">
#                                     [Energy - 577Cal | Protein - 23gm] Bite into the flavourful layers of
#                                 </section>
# </article>
# </div>
# <article class="itemCountHolder">
# <div>
# <button class="countCta add">Loading</button>
# </div>
# </article>
# </section>
# </article>
# <article class="categoryListing">
# <h4 class="categoryHeading"> Chinese Fried Rice &amp; Noodle Bowl </h4>
# <section class="categoryItemHolder">
# <div class="itemDetails itemWithImage">
# <a href="https://magicpin.in/New-Delhi/Paharganj/Restaurant/product/Chilli-Garlic-Paneer/?itemId=64258479&amp;mid=19401813&amp;utm_source=popular_items&amp;lat=28.6409887&amp;lon=77.2101869">
# <span class="itemImageHolder">
# <img alt="Chilli Garlic Paneer image" class="itemImage" src="https://static.magicpin.com/samara/static/images/blank-placeholder.svg"/>
# </span>
# </a>
# <article class="itemInfo">
# <a class="itemName" href="https://magicpin.in/New-Delhi/Paharganj/Restaurant/product/Chilli-Garlic-Paneer/?itemId=64258479&amp;mid=19401813&amp;utm_source=popular_items&amp;lat=28.6409887&amp;lon=77.2101869">Chilli Garlic Paneer</a>
# <p>
# <span class="itemPrice"> ₹260 </span>
# </p>
# <section class="description">
#                                     An Indo-Chinese dish with a perfect balance of heat and tang. Soft pan
#                                 </section>
# </article>
# </div>
# <article class="itemCountHolder">
# <div>
# <button class="countCta add">Loading</button>
# </div>
# </article>
# </section>
# <section class="categoryItemHolder">
# <div class="itemDetails itemWithImage">
# <a href="https://magicpin.in/New-Delhi/Paharganj/Restaurant/product/Chilli-Garlic-Chicken/?itemId=64258478&amp;mid=19401813&amp;utm_source=popular_items&amp;lat=28.6409887&amp;lon=77.2101869">
# <span class="itemImageHolder">
# <img alt="Chilli Garlic Chicken image" class="itemImage" src="https://static.magicpin.com/samara/static/images/blank-placeholder.svg"/>
# </span>
# </a>
# <article class="itemInfo">
# <a class="itemName" href="https://magicpin.in/New-Delhi/Paharganj/Restaurant/product/Chilli-Garlic-Chicken/?itemId=64258478&amp;mid=19401813&amp;utm_source=popular_items&amp;lat=28.6409887&amp;lon=77.2101869">Chilli Garlic Chicken</a>
# <p>
# <span class="itemPrice"> ₹330 </span>
# </p>
# <section class="description">
#                                     An Indo-Chinese dish with a perfect balance of heat and tang. Succulen
#                                 </section>
# </article>
# </div>
# <article class="itemCountHolder">
# <div>
# <button class="countCta add">Loading</button>
# </div>
# </article>
# </section>
# <section class="categoryItemHolder">
# <div class="itemDetails itemWithImage">
# <a href="https://magicpin.in/New-Delhi/Paharganj/Restaurant/product/Chilli-Garlic-Paneer-Fried-Rice-Bowl/?itemId=64258475&amp;mid=19401813&amp;utm_source=popular_items&amp;lat=28.6409887&amp;lon=77.2101869">
# <span class="itemImageHolder">
# <img alt="Chilli Garlic Paneer Fried Rice Bowl image" class="itemImage" src="https://static.magicpin.com/samara/static/images/blank-placeholder.svg"/>
# </span>
# </a>
# <article class="itemInfo">
# <a class="itemName" href="https://magicpin.in/New-Delhi/Paharganj/Restaurant/product/Chilli-Garlic-Paneer-Fried-Rice-Bowl/?itemId=64258475&amp;mid=19401813&amp;utm_source=popular_items&amp;lat=28.6409887&amp;lon=77.2101869">Chilli Garlic Paneer Fried Rice Bowl</a>
# <p>
# <span class="itemPrice"> ₹288 </span>
# </p>
# <section class="description">
#                                             A popular Chinese-style dish made with cooked rice stir-fried with a m
#                                         </section>
# </article>
# </div>
# <article class="itemCountHolder">
# <div>
# <button class="countCta add">Loading</button>
# </div>
# </article>
# </section>
# <section class="categoryItemHolder">
# <div class="itemDetails itemWithImage">
# <a href="https://magicpin.in/New-Delhi/Paharganj/Restaurant/product/Chilli-Garlic-Chicken-Fried-Rice-Bowl/?itemId=64258476&amp;mid=19401813&amp;utm_source=popular_items&amp;lat=28.6409887&amp;lon=77.2101869">
# <span class="itemImageHolder">
# <img alt="Chilli Garlic Chicken Fried Rice Bowl image" class="itemImage" src="https://static.magicpin.com/samara/static/images/blank-placeholder.svg"/>
# </span>
# </a>
# <article class="itemInfo">
# <a class="itemName" href="https://magicpin.in/New-Delhi/Paharganj/Restaurant/product/Chilli-Garlic-Chicken-Fried-Rice-Bowl/?itemId=64258476&amp;mid=19401813&amp;utm_source=popular_items&amp;lat=28.6409887&amp;lon=77.2101869">Chilli Garlic Chicken Fried Rice Bowl</a>
# <p>
# <span class="itemPrice"> ₹308 </span>
# </p>
# <section class="description">
#                                             A popular Chinese-style dish made with cooked rice stir-fried with a m
#                                         </section>
# </article>
# </div>
# <article class="itemCountHolder">
# <div>
# <button class="countCta add">Loading</button>
# </div>
# </article>
# </section>
# </article>
# <article class="categoryListing">
# <h4 class="categoryHeading"> 3 Layer Rice Bowl </h4>
# <section class="categoryItemHolder">
# <div class="itemDetails itemWithImage">
# <a href="https://magicpin.in/New-Delhi/Paharganj/Restaurant/product/Kadhai-Paneer,-Soya-Masala-Sabzi-And-Jeera-Pulao/?itemId=2857630&amp;mid=19401813&amp;utm_source=popular_items&amp;lat=28.6409887&amp;lon=77.2101869">
# <span class="itemImageHolder">
# <img alt="Kadhai Paneer, Soya Masala Sabzi &amp; Jeera Pulao image" class="itemImage" src="https://static.magicpin.com/samara/static/images/blank-placeholder.svg"/>
# </span>
# </a>
# <article class="itemInfo">
# <a class="itemName" href="https://magicpin.in/New-Delhi/Paharganj/Restaurant/product/Kadhai-Paneer,-Soya-Masala-Sabzi-And-Jeera-Pulao/?itemId=2857630&amp;mid=19401813&amp;utm_source=popular_items&amp;lat=28.6409887&amp;lon=77.2101869">Kadhai Paneer, Soya Masala Sabzi &amp; Jeera Pulao</a>
# <p>
# <span class="itemPrice"> ₹259 </span>
# </p>
# <section class="description">
#                                     A flavourful rice bowl with delicious kadhai paneer, yumm soya masala
#                                 </section>
# </article>
# </div>
# <article class="itemCountHolder">
# <div>
# <button class="countCta add">Loading</button>
# </div>
# </article>
# </section>
# <section class="categoryItemHolder">
# <div class="itemDetails itemWithImage">
# <a href="https://magicpin.in/New-Delhi/Paharganj/Restaurant/product/Yellow-Dal-Tadka,-Bhindi-Chana-And-Jeera-Pulao/?itemId=2857632&amp;mid=19401813&amp;utm_source=popular_items&amp;lat=28.6409887&amp;lon=77.2101869">
# <span class="itemImageHolder">
# <img alt="Yellow Dal Tadka, Bhindi Chana &amp; Jeera Pulao image" class="itemImage" src="https://static.magicpin.com/samara/static/images/blank-placeholder.svg"/>
# </span>
# </a>
# <article class="itemInfo">
# <a class="itemName" href="https://magicpin.in/New-Delhi/Paharganj/Restaurant/product/Yellow-Dal-Tadka,-Bhindi-Chana-And-Jeera-Pulao/?itemId=2857632&amp;mid=19401813&amp;utm_source=popular_items&amp;lat=28.6409887&amp;lon=77.2101869">Yellow Dal Tadka, Bhindi Chana &amp; Jeera Pulao</a>
# <p>
# <span class="itemPrice"> ₹229 </span>
# </p>
# <section class="description">
#                                     This is a bowl bursting with goodness of protein from whole foods! Sat
#                                 </section>
# </article>
# </div>
# <article class="itemCountHolder">
# <div>
# <button class="countCta add">Loading</button>
# </div>
# </article>
# </section>
# <section class="categoryItemHolder">
# <div class="itemDetails itemWithImage">
# <a href="https://magicpin.in/New-Delhi/Paharganj/Restaurant/product/Ghar-Ke-Rajma,-Aloo-Gobhi-And-Jeera-Pulao/?itemId=2857635&amp;mid=19401813&amp;utm_source=popular_items&amp;lat=28.6409887&amp;lon=77.2101869">
# <span class="itemImageHolder">
# <img alt="Ghar Ke Rajma, Aloo Gobhi &amp; Jeera Pulao image" class="itemImage" src="https://static.magicpin.com/samara/static/images/blank-placeholder.svg"/>
# </span>
# </a>
# <article class="itemInfo">
# <a class="itemName" href="https://magicpin.in/New-Delhi/Paharganj/Restaurant/product/Ghar-Ke-Rajma,-Aloo-Gobhi-And-Jeera-Pulao/?itemId=2857635&amp;mid=19401813&amp;utm_source=popular_items&amp;lat=28.6409887&amp;lon=77.2101869">Ghar Ke Rajma, Aloo Gobhi &amp; Jeera Pulao</a>
# <p>
# <span class="itemPrice"> ₹239 </span>
# </p>
# <section class="description">
#                                     What’s better than a rice bowl? A rajma rice bowl! Indulge in the whol
#                                 </section>
# </article>
# </div>
# <article class="itemCountHolder">
# <div>
# <button class="countCta add">Loading</button>
# </div>
# </article>
# </section>
# <section class="categoryItemHolder">
# <div class="itemDetails itemWithImage">
# <a href="https://magicpin.in/New-Delhi/Paharganj/Restaurant/product/Butter-Paneer,-Aloo-Gobhi-And-Jeera-Pulao/?itemId=2857638&amp;mid=19401813&amp;utm_source=popular_items&amp;lat=28.6409887&amp;lon=77.2101869">
# <span class="itemImageHolder">
# <img alt="Butter Paneer, Aloo Gobhi &amp; Jeera Pulao image" class="itemImage" src="https://static.magicpin.com/samara/static/images/blank-placeholder.svg"/>
# </span>
# </a>
# <article class="itemInfo">
# <a class="itemName" href="https://magicpin.in/New-Delhi/Paharganj/Restaurant/product/Butter-Paneer,-Aloo-Gobhi-And-Jeera-Pulao/?itemId=2857638&amp;mid=19401813&amp;utm_source=popular_items&amp;lat=28.6409887&amp;lon=77.2101869">Butter Paneer, Aloo Gobhi &amp; Jeera Pulao</a>
# <p>
# <span class="itemPrice"> ₹268 </span>
# </p>
# <section class="description">
#                                     This super bowl brings the best of all worlds together with its wholes
#                                 </section>
# </article>
# </div>
# <article class="itemCountHolder">
# <div>
# <button class="countCta add">Loading</button>
# </div>
# </article>
# </section>
# <section class="categoryItemHolder">
# <div class="itemDetails itemWithImage">
# <a href="https://magicpin.in/New-Delhi/Paharganj/Restaurant/product/Lasooni-Methi-Paneer,-Soya-Masala-Sabzi-And-Jeera-Pulao/?itemId=2857640&amp;mid=19401813&amp;utm_source=popular_items&amp;lat=28.6409887&amp;lon=77.2101869">
# <span class="itemImageHolder">
# <img alt="Lasooni Methi Paneer, Soya Masala Sabzi &amp; Jeera Pulao image" class="itemImage" src="https://static.magicpin.com/samara/static/images/blank-placeholder.svg"/>
# </span>
# </a>
# <article class="itemInfo">
# <a class="itemName" href="https://magicpin.in/New-Delhi/Paharganj/Restaurant/product/Lasooni-Methi-Paneer,-Soya-Masala-Sabzi-And-Jeera-Pulao/?itemId=2857640&amp;mid=19401813&amp;utm_source=popular_items&amp;lat=28.6409887&amp;lon=77.2101869">Lasooni Methi Paneer, Soya Masala Sabzi &amp; Jeera Pulao</a>
# <p>
# <span class="itemPrice"> ₹259 </span>
# </p>
# <section class="description">
#                                     This ain’t just a rice bowl! This is a protein bowl. Garlicky methi pa
#                                 </section>
# </article>
# </div>
# <article class="itemCountHolder">
# <div>
# <button class="countCta add">Loading</button>
# </div>
# </article>
# </section>
# <section class="categoryItemHolder">
# <div class="itemDetails itemWithImage">
# <a href="https://magicpin.in/New-Delhi/Paharganj/Restaurant/product/Yellow-Dal-Tadka,-Soya-Masala-Sabzi-And-Jeera-Pulao/?itemId=2857645&amp;mid=19401813&amp;utm_source=popular_items&amp;lat=28.6409887&amp;lon=77.2101869">
# <span class="itemImageHolder">
# <img alt="Yellow Dal Tadka, Soya Masala Sabzi &amp; Jeera Pulao image" class="itemImage" src="https://static.magicpin.com/samara/static/images/blank-placeholder.svg"/>
# </span>
# </a>
# <article class="itemInfo">
# <a class="itemName" href="https://magicpin.in/New-Delhi/Paharganj/Restaurant/product/Yellow-Dal-Tadka,-Soya-Masala-Sabzi-And-Jeera-Pulao/?itemId=2857645&amp;mid=19401813&amp;utm_source=popular_items&amp;lat=28.6409887&amp;lon=77.2101869">Yellow Dal Tadka, Soya Masala Sabzi &amp; Jeera Pulao</a>
# <p>
# <span class="itemPrice"> ₹229 </span>
# </p>
# <section class="description">
#                                     This is your comforting and nutritious meal - yellow dal tadka, soya c
#                                 </section>
# </article>
# </div>
# <article class="itemCountHolder">
# <div>
# <button class="countCta add">Loading</button>
# </div>
# </article>
# </section>
# <section class="categoryItemHolder">
# <div class="itemDetails itemWithImage">
# <a href="https://magicpin.in/New-Delhi/Paharganj/Restaurant/product/Kadhai-Paneer,-Bhindi-Chana-And-Jeera-Pulao/?itemId=52237517&amp;mid=19401813&amp;utm_source=popular_items&amp;lat=28.6409887&amp;lon=77.2101869">
# <span class="itemImageHolder">
# ...
#                     for (const ratingHolder of ratingHolders) {
#                         ratingHolder.innerText = randomRating;
#                     }
#
#                     document.cookie = "vrr=" + randomRating + ";path=/";
#                 }
#
#                 rando.style.display = "inline-block";
#             }
#         })()
#
#         function reviewShort() {
#             var showChar = 170;
#             var ellipsestext = "...";
#             var moretext = "show more";
#             var lesstext = "show less";
#
#             document.querySelectorAll('.long-review').forEach(function(elem) {
#                 var content = elem.innerHTML;
#                 if(content.length > showChar) {
#                     if(content[showChar] != " "){
#                         while(showChar < content.length && content[showChar] != " ") {
#                             showChar++;
#                         }
#                     }
#
#                     if(content[showChar] == " " && content[showChar-1] == "a" && content[showChar-2] == "<"){
#                         showChar = showChar - 3
#                     }
#
#                     var shortReview = content.substr(0, showChar);
#                     var fullReview = content.substr(showChar, content.length - showChar);
#
#                     var finalReview = shortReview + '<span>' + ellipsestext+ '</span><span class="morecontent"><span class="fullreview">' + fullReview + '</span> <a href="" class="morelink">' + moretext + '</a></span>';
#
#                     elem.innerHTML = finalReview;
#                 }
#
#             });
#
#             const moreLink = document.querySelectorAll(".morelink")
#             for(let i=0;i<moreLink.length;i++) {
#                 moreLink[i].onclick = function(e){
#                     e.preventDefault()
#                     if(this.classList.contains("less")) {
#                         this.classList.remove("less");
#                         this.innerHTML = moretext;
#                     } else {
#                         this.classList.add("less");
#                         this.innerHTML = lesstext;
#                     }
#                     toggleElement(this.parentElement.previousElementSibling, true);
#                     toggleElement(this.previousElementSibling, false);
#                     return false;
#                 };
#             }
#         }
#
#         function loadReview() {
#             const shortReview = document.querySelectorAll('.short-review')
#             for(let i=0;i<shortReview.length;i++) {
#                 shortReview[i].parentElement.style.height = "auto";
#                 shortReview[i].style.display = "none"
#                 if(i<5) {
#                     shortReview[i].style.display = "initial"
#                 }
#             }
#             const viewMore = document.querySelector("#view-more")
#             if(viewMore) {
#                 viewMore.onclick = function (e) {
#                     e.preventDefault();
#                     let vis = 0;
#                     for(let i=0;i<shortReview.length;i++) {
#                         if(shortReview[i].style.display == "none") {
#                             vis++;
#                             shortReview[i].style.display = "initial"
#                         }
#                     }
#                 }
#             }
#         }
#
#
#         isMobile = window.innerWidth < 800
#         reviewShort()
#         if(!isMobile) {
#             loadScript("https://code.jquery.com/jquery-3.7.1.js", () => {
#
#
#             })
#         }
#
#         let device = window.innerWidth > 800 ? 'desktop' : 'mobile'
#
#
#
#
#             hideExtras(`.hide-subcat-${device}`, `#show-more-cuisines-${device}`, "inline-flex")
#
#
#
#         function hideAlbumsArrow(eventName) {
#             let albumDiv = document.querySelector('.albumsHolder')
#             if(albumDiv && !(albumDiv.scrollWidth > albumDiv.clientWidth)) {
#                 document.querySelectorAll('.albumsHolder .nextArrow').forEach(arrow => arrow.style.display = "none")
#             }
#
#             sendEvent('web_merchantpage_delivery', "click", `see_more_${eventName}`, {"subject_type": "merchant", "subject_id": "19401813"})
#         }
#
#         window.addEventListener("load", hideAlbumsArrow)
#
#         function hideExtras(extraSelector, showMoreSelector, displayProperty="inline-block") {
#             let extraItems = document.querySelectorAll(extraSelector)
#             let showExtraCta = document.querySelector(showMoreSelector)
#
#             if(showExtraCta && extraItems) {
#                 if (extraItems.length == 0) {
#                     showExtraCta.style.display = "none";
#                     return;
#                 }
#                 showExtraCta.innerText = `+${extraItems.length} more`
#                 showExtraCta.style.display = "inline-block"
#                 showExtraCta.addEventListener('click', () => {
#                     extraItems.forEach(extraItem => {extraItem.style.display = displayProperty})
#                     showExtraCta.style.display = "none"
#                 })
#             }
#         }
#
#         function scrollVideos() {
#             document.querySelector('.merchant-video-holder.hide-mb').scrollLeft += 232
#         }
#
#
#
#
#
#
#
#             if(window.innerWidth > 800) {
#                 let sidebar = document.querySelector('.sidebar')
#                 let sidebarOffset = sidebar.offsetTop
#                 window.addEventListener('scroll', () => stickSidebar(sidebarOffset))
#
#                 function stickSidebar(sidebarOffset) {
#                     let sidebar = document.querySelector('.sidebar')
#                     let headerOffsetHeight = document.querySelector('.site-header').offsetHeight
#                     let totalScoll = window.scrollY + headerOffsetHeight
#                     if(totalScoll > sidebarOffset) {
#                         sidebar.classList.add('stick')
#                         let closeAnnounce = readCookie('closeAnnounce');
#                         if(closeAnnounce){
#                             sidebar.style.top = "90px"
#                         }else{
#                             sidebar.style.top = "140px"
#                         }
#                     } else {
#                         if(sidebar.classList.contains('stick')) {
#                             sidebar.classList.remove('stick')
#                             sidebar.style.top = "0px"
#                         }
#                     }
#                 }
#             }
#
#
#     </script>
# <script>
#         window.pageProps =  JSON.parse(`{\u0022starting_from\u0022: 0, \u0022total_outlets\u0022: 0, \u0022sign_up_bonus\u0022: 500, \u0022is_fashion_delivery_merchant\u0022: false, \u0022book_deal_available\u0022: false, \u0022merchant\u0022: {\u0022city\u0022: \u0022New Delhi\u0022, \u0022lon\u0022: 77.2101869, \u0022locality\u0022: \u0022Paharganj\u0022, \u0022distance\u0022: 0, \u0022name\u0022: \u0022EatFit\u0022, \u0022localitySecondaryNames\u0022: null, \u0022address\u0022: \u00221830\u002D1831, Gf, Laxmi Narain Street, Chuna Mandi, Paharganj, Delhi, New Delhi, Delhi\u002D110055, Paharganj, New Delhi\u0022, \u0022lat\u0022: 28.6409887, \u0022title\u0022: \u0022ADDRESS\u0022}, \u0022page_name\u0022: \u0022magicorderpage\u0022, \u0022selected_menu\u0022: \u0022All\u0022, \u0022user_stories_widget\u0022: {}, \u0022url_merchant_id\u0022: \u002261a193\u0022, \u0022menus\u0022: [\u0022All\u0022, \u0022Food Menu\u0022], \u0022photos\u0022: {\u0022name\u0022: \u0022store_images\u0022, \u0022title\u0022: \u0022Photos\u0022, \u0022more_images\u0022: [{\u0022image\u0022: \u0022https://lh3.googleusercontent.com/k\u002DiN\u002DGta3oUpCYBSGHRPsDpo5Cv4lstaI6eAdK_1PBy0z_ofmJwL1R4P6pnRsWMNEkg0slV0UUwWf80yRDa7Dw2hZdxfdJzO7DKG89WhmA\u003Dw1200\u002Drw\u0022, \u0022url\u0022: null}, {\u0022image\u0022: \u0022https://lh3.googleusercontent.com/E9RiSdrWUltyEzOrAguHR_5x512zsPddIkPH1k5ZH70ZR4r3KLov6kELxPDxqlHkkWN2mSI00gAjpabgUy1TzhhKJDLXxR7NffHEGg4\u003Dw1200\u002Drw\u0022, \u0022url\u0022: null}, {\u0022image\u0022: \u0022https://lh3.googleusercontent.com/0jfFV\u002DdFfSL5CUH01eWQKkQvjzxt7IkA1D2wIH6lXM7l4xo88IiVyoj\u002DiR34nC8BeEgIYO2X0ErymUhzYrlwPvPKS3tcYx4keI257Iwkog\u003Dw256\u002Drw\u0022, \u0022url\u0022: null}]}, \u0022enable_order_booking\u0022: true, \u0022company_group_id\u0022: \u0022\u0022, \u0022selected_menu_images\u0022: [{\u0022image\u0022: \u0022https://lh3.googleusercontent.com/PIr1CZ7sg1IvWIXKSOGuA7rbBpMn8Tayl\u002D8Hgf5JuJScOsBDQ4cXV2_ZaU\u002DrvAEbQ2m8taSd95zskkeXyL7PsZeqkFmBXCImrax8_y4T\u003Dw1200\u002Drw\u0022, \u0022url\u0022: null}, {\u0022image\u0022: \u0022https://lh3.googleusercontent.com/h0nGo0FPBKlhQtFek3XwpTT2mOhe2iDgJaOnCPg_rz_TxAx6jTn9rkauXqt5mh4BI5CQjesAf6Ld_ac7AoTnB9SuvKk6VA1ef_yWmvkl\u003Dw1200\u002Drw\u0022, \u0022url\u0022: null}, {\u0022image\u0022: \u0022https://lh3.googleusercontent.com/06hacotM7QnChzKgT8ioMDFkrTWNkt3WFysnFoU9G0EvmVqlCBqkftxSCLQ7GrJhlP0H95rwJ1vEjKbXJ5SdaobecSbKDoCQ2Pi\u002DVJ0HIw\u003Dw1200\u002Drw\u0022, \u0022url\u0022: null}], \u0022magicpay_amount\u0022: null, \u0022payment_offers\u0022: null, \u0022album_type\u0022: {\u0022misc_heading\u0022: \u0022Misc Images\u0022, \u0022heading_slug\u0022: \u0022Store\u002DImages\u0022, \u0022merchant_videos_slug\u0022: \u0022videos\u0022, \u0022selfie_heading\u0022: \u0022Customer Images\u0022, \u0022misc_slug\u0022: \u0022Misc\u002DImages\u0022, \u0022main_heading\u0022: \u0022Store Images\u0022, \u0022catalog_slug\u0022: \u0022Catalogue\u002DImages\u0022, \u0022selfie_slug\u0022: \u0022Customer\u002DImages\u0022, \u0022merchant_videos\u0022: \u0022Videos\u0022, \u0022catalog_heading\u0022: \u0022Catalogue Images\u0022}, \u0022is_beyond_food_merchant\u0022: false, \u0022expandGallery\u0022: null, \u0022album\u0022: [{\u0022name\u0022: \u0022store_images\u0022, \u0022title\u0022: \u0022Photos\u0022, \u0022more_images\u0022: [{\u0022image\u0022: \u0022https://lh3.googleusercontent.com/k\u002DiN\u002DGta3oUpCYBSGHRPsDpo5Cv4lstaI6eAdK_1PBy0z_ofmJwL1R4P6pnRsWMNEkg0slV0UUwWf80yRDa7Dw2hZdxfdJzO7DKG89WhmA\u003Dw1200\u002Drw\u0022, \u0022url\u0022: null}, {\u0022image\u0022: \u0022https://lh3.googleusercontent.com/E9RiSdrWUltyEzOrAguHR_5x512zsPddIkPH1k5ZH70ZR4r3KLov6kELxPDxqlHkkWN2mSI00gAjpabgUy1TzhhKJDLXxR7NffHEGg4\u003Dw1200\u002Drw\u0022, \u0022url\u0022: null}, {\u0022image\u0022: \u0022https://lh3.googleusercontent.com/0jfFV\u002DdFfSL5CUH01eWQKkQvjzxt7IkA1D2wIH6lXM7l4xo88IiVyoj\u002DiR34nC8BeEgIYO2X0ErymUhzYrlwPvPKS3tcYx4keI257Iwkog\u003Dw256\u00 ...
#
#         window.magicOrderSSR = document.getElementById('magic-order-react').innerHTML;
#
#         window.mountMerchantTiming = document.getElementById('merchant-timing-react');
#         window.mountMerchantImages = document.getElementById('merchant-images-react');
#         window.mountMerchantGallery = document.getElementById('merchant-gallery-react');
#         window.mountMerchantMenuGallery = document.getElementById('merchant-menu-gallery-react');
#         window.mountMerchantVoucher = document.getElementById('merchant-voucher-react');
#         window.mountMerchantVoucherSummary = document.getElementById('merchant-voucher-summary-react');
#         window.allowMagicpayPhonepe =  true ;
#         window.mountVoucherWidget = document.getElementById("voucher-widget-react");
#         window.mountMenuImagesSlick = document.getElementById('menu-images-slick-react');
#         window.mountNewUserOfferBanner = document.getElementsByClassName('new-user-offer-banner-react')
#         window.mountMagicOrderStrip = document.getElementById('magic-order-strip-react')
#         window.mountMerchantStrips = document.getElementById('merchant-strips-react')
#         window.mountMerchantPhotosNew = document.getElementById('merchant-photos-react')
#         window.mountPhoneNumOptionsDialog = document.getElementById('phone-num-options-dialog')
#         window.mountCreateCustomVoucher = document.getElementById('create-custom-voucher-react')
#         window.mountBottomMagicpayStrip = document.getElementById('magicpay-bottom-strip-react');
#         window.mountMerchantAlbum = document.getElementsByClassName('merchant-album-widget-react')
#         window.mountAppInstallCouponCodeOffer = document.getElementById('app-install-coupon-code-offer-react');
#         window.mountMagicOrder = document.getElementById('magic-order-react');
#         window.mountMerchantOrderSummary = document.getElementById('merchant-order-summary-react');
#         window.mountChainOutlets = document.getElementById('merchant-chain-outlets-react');
#         window.mountPostPagination = document.getElementById('post-pagination-react');
#         window.mountPaymentFailurePopup = document.getElementById('payment-failure-popup-react');
#         window.socialBuzzReact = document.getElementById("social-buzz-react");
#
#
#         if(window.innerWidth < 800 && window.pageProps) {
#             const isDeliveryPage = pageProps.page_type === "delivery" ? true : false;
#             const navHolder = document.querySelector('#nav-holder');
#             const merchantNav = document.querySelector('.merchant-navigation')
#             navHolder.style.height = merchantNav.clientHeight + "px";
#             const site_header = document.querySelector(".site-header");
#             window.addEventListener('scroll', () => {
#                 let offsetTop = navHolder.offsetTop;
#                 if (isDeliveryPage) {
#                     offsetTop = offsetTop + merchantNav.clientHeight;
#                 }
#
#                 if(window.scrollY > offsetTop) {
#                     merchantNav.style.position = "fixed"
#                     if (isDeliveryPage) {
#                         site_header.style.display = "none"
#                         merchantNav.style.top = "0px";
#                     } else {
#                         merchantNav.style.top = site_header.clientHeight + "px"
#                     }
#                 } else if(window.scrollY < offsetTop) {
#                     merchantNav.style.position = "static";
#                     isDeliveryPage ? site_header.style.display = "block" : null;
#                 }
#             },{
#                 passive: true
#             })
#         }
#
#     </script>
# <script>
#         window.addEventListener('load', function() {
#             loadScript("https://code.jquery.com/jquery-3.7.1.js",() => {
#                 jQuery('body').on('mousedown', '.add,.voucher-button-add,.voucher-price-button,.voucher-counter,.voucher-final-price,.addCTA,.countCta', function() {
#                     gtag('event', 'conversion', {'send_to': 'AW-10999901866/L-D8CMfrjeYDEKrdlP0o'});
#                 })
#             })
#         });
#     </script>
# <script>
#         window.socialBuzzLoaded = false;
#         window.socialBuzzLoading = false;
#
#         function openSocialBuzz(index) {
#             if (window.socialBuzzLoading) return;
#             if (socialBuzzLoaded) {
#                 typeof sendEvent === "function" && sendEvent("web_" + window.pageName, "social_buzz", "opened");
#                 document.dispatchEvent(new CustomEvent('custom_open_user_story', {detail:{index}}))
#             } else {
#                 typeof window.loadSocialBuzz == "function" && window.loadSocialBuzz(index);
#             }
#         }
#     </script>
# <script type="text/javascript">
#     _linkedin_partner_id = "5580401";
#     window._linkedin_data_partner_ids = window._linkedin_data_partner_ids || [];
#     window._linkedin_data_partner_ids.push(_linkedin_partner_id);
#     </script><script type="text/javascript">
#     (function(l) {
#     if (!l){window.lintrk = function(a,b){window.lintrk.q.push([a,b])};
#     window.lintrk.q=[]}
#     var s = document.getElementsByTagName("script")[0];
#     var b = document.createElement("script");
#     b.type = "text/javascript";b.async = true;
#     b.src = "https://snap.licdn.com/li.lms-analytics/insight.min.js";
#     s.parentNode.insertBefore(b, s);})(window.lintrk);
#     </script>
# <noscript>
# <img alt="" height="1" src="https://px.ads.linkedin.com/collect/?pid=5580401&amp;fmt=gif" style="display:none;" width="1"/>
# </noscript>
# </body>
# </html>

# %%
# Find the relevant div with class 'itemDetails'
#item_details_div = soup.find_all('div', class_='itemDetails')
catalog_items = soup.find_all('div', class_='catalogItemsHolder')

# %%
# List to store item information
items_list = []

# %%
for catalog_item in catalog_items:
    # Find all sections with class 'categoryItemHolder' within the current 'catalogItemsHolder'
    item_sections = catalog_item.find_all('section', class_='categoryItemHolder')

    for item_section in item_sections:
        # Find the relevant div with class 'itemDetails' within the current 'categoryItemHolder'
        item_details_div = item_section.find('div', class_='itemDetails')

        # Extract itemName and itemPrice
        item_name = item_details_div.find('a', class_='itemName').text.strip()
        item_price = item_details_div.find('span', class_='itemPrice').text.strip()

        # Add item information to the list
        items_list.append({'Item Name': item_name, 'Item Price': item_price})

# %%
# Print or use the items_list as needed
for item in items_list:
    print(f'Item Name: {item["Item Name"]}')
    print(f'Item Price: {item["Item Price"]}')
    print('-' * 20)
# Out:
# Item Name: Veg Keema Kulcha Burger
# Item Price: ₹239
# --------------------
# Item Name: Peri-Peri Paneer Kulcha Burger
# Item Price: ₹308
# --------------------
# Item Name: Peri-Peri Chicken Kulcha Burger
# Item Price: ₹319
# --------------------
# Item Name: Chilli Garlic Paneer
# Item Price: ₹260
# --------------------
# Item Name: Chilli Garlic Chicken
# Item Price: ₹330
# --------------------
# Item Name: Chilli Garlic Paneer Fried Rice Bowl
# Item Price: ₹288
# --------------------
# Item Name: Chilli Garlic Chicken Fried Rice Bowl
# Item Price: ₹308
# --------------------
# Item Name: Kadhai Paneer, Soya Masala Sabzi & Jeera Pulao
# Item Price: ₹259
# --------------------
# Item Name: Yellow Dal Tadka, Bhindi Chana & Jeera Pulao
# Item Price: ₹229
# --------------------
# Item Name: Ghar Ke Rajma, Aloo Gobhi & Jeera Pulao
# Item Price: ₹239
# --------------------
# Item Name: Butter Paneer, Aloo Gobhi & Jeera Pulao
# Item Price: ₹268
# --------------------
# Item Name: Lasooni Methi Paneer, Soya Masala Sabzi & Jeera Pulao
# Item Price: ₹259
# --------------------
# Item Name: Yellow Dal Tadka, Soya Masala Sabzi & Jeera Pulao
# Item Price: ₹229
# --------------------
# Item Name: Kadhai Paneer, Bhindi Chana & Jeera Pulao
# Item Price: ₹268
# --------------------
# Item Name: Dal Tadka, Bhindi Chana & Millet Pulao
# Item Price: ₹239
# --------------------
# Item Name: Lasooni Methi Paneer, Soya Matar & Millet Pulao
# Item Price: ₹258
# --------------------
# Item Name: Chole, Bhindi Chana & Millet Pulao
# Item Price: ₹228
# --------------------
# Item Name: Palak Paneer, Soya Matar & Millet Pulao
# Item Price: ₹267
# --------------------
# Item Name: Butter Paneer, Bhindi Chana & Millet Pulao
# Item Price: ₹268
# --------------------
# Item Name: Kadhai Chicken, Soya Masala Sabzi & Jeera Pulao
# Item Price: ₹288
# --------------------
# Item Name: Butter Chicken, Aloo Gobhi & Jeera Pulao
# Item Price: ₹288
# --------------------
# Item Name: Lasooni Methi Chicken, Soya Masala Sabzi & Jeera Pulao
# Item Price: ₹279
# --------------------
# Item Name: Lasooni Methi Chicken, Bhindi Chana & Jeera Pulao
# Item Price: ₹279
# --------------------
# Item Name: Kadhai Chicken, Bhindi Chana & Jeera Pulao
# Item Price: ₹288
# --------------------
# Item Name: Butter Chicken, Bhindi Chana & Millet Pulao
# Item Price: ₹288
# --------------------
# Item Name: Palak Chicken, Soya Matar & Millet Pulao
# Item Price: ₹287
# --------------------
# Item Name: Kadhai Paneer Deluxe Thali
# Item Price: ₹399
# --------------------
# Item Name: Palak Paneer Deluxe Thali
# Item Price: ₹398
# --------------------
# Item Name: Butter Paneer Deluxe Thali
# Item Price: ₹407
# --------------------
# Item Name: Palak Paneer Fit Thali
# Item Price: ₹318
# --------------------
# Item Name: Lasooni Methi Paneer Fit Thali
# Item Price: ₹307
# --------------------
# Item Name: Dal Makhani Fit Thali
# Item Price: ₹278
# --------------------
# Item Name: Butter Paneer Fit Thali
# Item Price: ₹327
# --------------------
# Item Name: Kadhai Paneer Fit Thali
# Item Price: ₹318
# --------------------
# Item Name: Yellow Dal Tadka Fit Thali
# Item Price: ₹258
# --------------------
# Item Name: Lasooni Methi Chicken Fit Thali
# Item Price: ₹327
# --------------------
# Item Name: Palak Chicken Fit Thali
# Item Price: ₹338
# --------------------
# Item Name: Kadhai Chicken Fit Thali
# Item Price: ₹338
# --------------------
# Item Name: Butter Chicken Fit Thali
# Item Price: ₹347
# --------------------
# Item Name: Yellow Dal Tadka, Bhindi Chana, Paratha Thali
# Item Price: ₹228
# --------------------
# Item Name: Lasooni Methi Paneer, Aloo Gobhi & Paratha Thali
# Item Price: ₹268
# --------------------
# Item Name: Kadhai Paneer, Soya Masala Sabzi, Paratha Thali
# Item Price: ₹279
# --------------------
# Item Name: Chole, Aloo Gobhi, Paratha Thali
# Item Price: ₹259
# --------------------
# Item Name: Palak Paneer, Dal Makhani, Parathas Thali
# Item Price: ₹277
# --------------------
# Item Name: Butter Paneer, Dal Makhani, Paratha Thali
# Item Price: ₹279
# --------------------
# Item Name: Kadhai Paneer, Bhindi Chana, Paratha Thali
# Item Price: ₹297
# --------------------
# Item Name: Kadhai Paneer, Yellow Dal Tadka, Paratha Thali
# Item Price: ₹298
# --------------------
# Item Name: Veg Keema, Yellow Dal Tadka, Paratha Thali
# Item Price: ₹259
# --------------------
# Item Name: Sarson Ka Saag, 3 Paratha Meal
# Item Price: ₹249
# --------------------
# Item Name: Kadhai Chicken, Soya Masala Sabzi, Paratha Thali
# Item Price: ₹319
# --------------------
# Item Name: Lasooni Methi Chicken, Yellow Dal Tadka, Paratha Thali
# Item Price: ₹299
# --------------------
# Item Name: Palak Chicken, Dal Makhani, Parathas Thali
# Item Price: ₹287
# --------------------
# Item Name: Masala Egg Curry, Yellow Dal Tadka, Paratha Thali
# Item Price: ₹249
# --------------------
# Item Name: Butter Chicken, Dal Makhani, Paratha Thali
# Item Price: ₹347
# --------------------
# Item Name: Classic Tomato Basil Penne Pasta
# Item Price: ₹288
# --------------------
# Item Name: Poha
# Item Price: ₹139
# --------------------
# Item Name: Baked Bhakarwadi (50g)
# Item Price: ₹59
# --------------------
# Item Name: Quinoa Bhujia (50g)
# Item Price: ₹69
# --------------------
# Item Name: Ragi Chips (50g)
# Item Price: ₹59
# --------------------
# Item Name: Chole Kulche
# Item Price: ₹199
# --------------------
# Item Name: Millet Curd Rice
# Item Price: ₹180
# --------------------
# Item Name: Whole Wheat Kulcha (2pcs)
# Item Price: ₹79
# --------------------
# Item Name: Whole Wheat Parathas (3pcs)
# Item Price: ₹68
# --------------------
# Item Name: Jeera Pulao (500g)
# Item Price: ₹149
# --------------------
# Item Name: Dal Makhani (420g)
# Item Price: ₹228
# --------------------
# Item Name: Butter Paneer (380g)
# Item Price: ₹328
# --------------------
# Item Name: Lasooni Methi Paneer (380g)
# Item Price: ₹299
# --------------------
# Item Name: Kadhai Paneer (380g)
# Item Price: ₹278
# --------------------
# Item Name: Sarson Ka Saag (380g)
# Item Price: ₹329
# --------------------
# Item Name: Lasooni Methi Chicken (400g)
# Item Price: ₹308
# --------------------
# Item Name: Butter Chicken (400g)
# Item Price: ₹339
# --------------------
# Item Name: Kadhai Chicken (400g)
# Item Price: ₹348
# --------------------
# Item Name: Badam Kheer
# Item Price: ₹79
# --------------------
# Item Name: Seviya Kheer
# Item Price: ₹99
# --------------------
# Item Name: Chocolate Nutty Dates Pudding
# Item Price: ₹99
# --------------------
# Item Name: Mango Phirni
# Item Price: ₹89
# --------------------
# Item Name: Millet Sabudana Kheer
# Item Price: ₹79
# --------------------
# Item Name: Panjiri Laddu (500g)
# Item Price: ₹399
# --------------------
# Item Name: Badam Kheer (400gm)
# Item Price: ₹153
# --------------------
# Item Name: Banana Walnut Cake
# Item Price: ₹89
# --------------------
# Item Name: Date Raisin Cake
# Item Price: ₹79
# --------------------
# Item Name: Chocolate Walnut Brownie
# Item Price: ₹79
# --------------------
# Item Name: Tender Coconut Water
# Item Price: ₹59
# --------------------
# Item Name: Classic Cold Coffee
# Item Price: ₹139
# --------------------
# Item Name: Aam Ka Panna (200ml)
# Item Price: ₹62
# --------------------
# Item Name: Mocha Shake
# Item Price: ₹99
# --------------------
# Item Name: Lemonade
# Item Price: ₹69
# --------------------
# Item Name: Mango (200ml)
# Item Price: ₹89
# --------------------
# Item Name: Mixed Fruit (200ml)
# Item Price: ₹89
# --------------------
# Item Name: Lemonade (200ml)
# Item Price: ₹75
# --------------------
# Item Name: Sugarcane (200ml)
# Item Price: ₹62
# --------------------
# Item Name: Pomegranate (200ml)
# Item Price: ₹107
# --------------------
# Item Name: Orange (200ml)
# Item Price: ₹107
# --------------------
